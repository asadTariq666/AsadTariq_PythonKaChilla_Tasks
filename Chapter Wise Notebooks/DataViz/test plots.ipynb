# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data = pd.read_csv('df.csv')
data.head()
# Out:
#   Genotype          species treatment       p1       p2       p3      g1  \
# 0      BEL  S. tuberosum 4x        T1  17.4000  14.1550  11.5800  1.2958
# 1   BGB009   S. commersonii        T1  15.8000  16.3000  12.9000  0.7810
# 2   BGB045   S. commersonii        T1  10.3000  10.6000  11.4000  0.5040
# 3   BGB083     S. chacoense        T1   5.8800  11.8000   2.1500  0.5960
# 4   BGB086     S. chacoense        T1  10.1875   8.4575   8.5025  0.6498
#
#        g2      g3      e1      e2      e3   fvfm1   fvfm2   fvfm3
# 0  0.4720  0.4698  7.7300  4.1453  4.8800  0.7688  0.7659  0.7534
# 1  0.5580  0.4280  6.5600  5.0400  5.1300  0.7627  0.7461  0.7289
# 2  0.4820  0.5890  6.2400  4.8000  5.8500  0.7538  0.7426  0.7488
# 3  0.4320  0.0507  6.6100  4.6800  1.1600  0.7355  0.7426  0.7163
# 4  0.2665  0.2440  5.0075  3.4725  3.7425  0.7691  0.7601  0.7604

# %%
plt.figure(figsize=(18,6))
sns.lineplot(data=data , x=data['Genotype'], y=data['p1'],ci=None)
sns.lineplot(data=data , x=data['Genotype'], y=data['p2'], ci=None)
sns.lineplot(data=data , x=data['Genotype'], y=data['p3'], ci=None)
plt.grid()
